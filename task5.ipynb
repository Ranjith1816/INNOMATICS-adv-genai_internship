# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranjith1816/INNOMATICS-adv-genai_internship/blob/main/task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.post engagement analyzer

# %%
def analyze_post_engagement(likes_list):
    total_likes = 0

    for like in likes_list:
        total_likes += like

    if total_likes >= 1000:
        status = "Viral Post"
    else:
        status = "Normal Engagement"

    print("Total Likes:", total_likes)
    print("Post Status:", status)

# Example
analyze_post_engagement([200, 300, 150, 400])
# Out:
# Total Likes: 1050
# Post Status: Viral Post

# %% [markdown]
# # 2.medicine stock alert system

# %%
def check_medicine_stock(stock):
    if stock < 10:
        status = "Low Stock Alert"
    else:
        status = "Stock Sufficient"

    print("Medicine Stock:", stock)
    print("Status:", status)

# Example
check_medicine_stock(25)
# Out:
# Medicine Stock: 25
# Status: Stock Sufficient

# %% [markdown]
# # 3.Rainfall adequacy checker

# %%
def check_rainfall(rainfall_list, required_level):
    total = 0

    for rain in rainfall_list:
        total += rain

    average = total / len(rainfall_list)

    if average >= required_level:
        status = "Adequate Rainfall"
    else:
        status = "Inadequate Rainfall"

    print("Average Rainfall:", average)
    print("Rainfall Status:", status)

# Example
check_rainfall([60, 70, 80, 78], 70)
# Out:
# Average Rainfall: 72.0
# Rainfall Status: Adequate Rainfall

# %% [markdown]
# # 4.dupilcate account detection

# %%
def detect_duplicates(usernames):
    if len(usernames) != len(set(usernames)):
        result = "Yes"
    else:
        result = "No"

    print("Duplicate Accounts Found:", result)

# Example
detect_duplicates(["user1", "user2", "user3", "user1"])
# Out:
# Duplicate Accounts Found: Yes

# %% [markdown]
# # 5.Appiontment eligibility checker.

# %%
def check_appointment_eligibility(age):
    if age >= 18:
        status = "Eligible"
    else:
        status = "Not Eligible"

    print("Patient Age:", age)
    print("Eligibility Status:", status)

# Example
check_appointment_eligibility(21)
# Out:
# Patient Age: 21
# Eligibility Status: Eligible

# %% [markdown]
# #6.premium crop price filter

# %%
def filter_premium_crops(price_list):
    premium = []

    for price in price_list:
        if price > 2000:
            premium.append(price)

    print("Premium Crops:", premium)

# Example
filter_premium_crops([1500, 2500, 3200, 1800])
# Out:
# Premium Crops: [2500, 3200]

# %% [markdown]
# #7.application health checker

# %%
def check_application_health(errors):
    if errors == 0:
        status = "Healthy"
    elif errors <= 5:
        status = "Minor Issues"
    else:
        status = "Critical Issues"

    print("Error Count:", errors)
    print("System Status:", status)

# Example
check_application_health(7)
# Out:
# Error Count: 7
# System Status: Critical Issues

# %% [markdown]
# #8.Daily transaction limit checker

# %%
def check_transaction(amount):
    daily_limit = 50000

    if amount <= daily_limit:
        status = "Approved"
    else:
        status = "Rejected"

    print("Transaction Amount:", amount)
    print("Transaction Status:", status)

# Example
check_transaction(60000)
# Out:
# Transaction Amount: 60000
# Transaction Status: Rejected

# %% [markdown]
# #9.Student attendance eligibility system

# %%
def check_attendance(attendance_list):
    total_classes = len(attendance_list)
    attended = 0

    for status in attendance_list:
        if status == "Present":
            attended += 1

    percentage = (attended / total_classes) * 100

    if percentage >= 75:
        eligibility = "Eligible"
    else:
        eligibility = "Not Eligible"

    print("Attendance Percentage:", percentage)
    print("Exam Eligibility:", eligibility)

# Example
check_attendance(["Present", "Present", "Absent", "Present", "Present"])
# Out:
# Attendance Percentage: 80.0
# Exam Eligibility: Eligible

# %% [markdown]
# #10. Smart electricity bill analyzer

# %%
def calculate_electricity_bill(units):
    bill = 0

    if units <= 100:
        bill = units * 3
    elif units <= 200:
        bill = (100 * 3) + ((units - 100) * 5)
    else:
        bill = (100 * 3) + (100 * 5) + ((units - 200) * 7)

    if bill < 500:
        usage = "Low Usage"
    elif bill <= 1500:
        usage = "Moderate Usage"
    else:
        usage = "High Usage"

    print("Total Bill:", bill)
    print("Usage Classification:", usage)

# Example
calculate_electricity_bill(250)
# Out:
# Total Bill: 1150
# Usage Classification: Moderate Usage
